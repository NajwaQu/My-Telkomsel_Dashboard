# %% [markdown]
# INSTALL LIBRARY

# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 474.3 kB/s eta 0:00:00
# ...

# %%
# !pip install pandas
# !pip install numpy

# %% [markdown]
# IMPORT LIBRARY

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.telkomsel.telkomselcm',
    lang = 'id',
    country = 'id',
    sort = Sort.NEWEST,
    count = 8000,
    filter_score_with = None
)

# %% [markdown]
# SHOW DATA YANG SUDAH DI CRAWLING

# %%
df_busu = pd.DataFrame(np.array(result), columns = ['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu.tail()
# Out:
#                                   reviewId         userName  \
# 7995  daf9c76d-eada-4bf9-be77-7c60cc0deeef  Pengguna Google
# 7996  330f1e80-ba60-4dc4-bd72-c75ec075606e  Pengguna Google
# 7997  4164a303-7459-4c19-93f7-528e2e7042a0  Pengguna Google
# 7998  cc36e9a0-389f-4ea4-ac58-5fc168db8cb4  Pengguna Google
# 7999  8583bfc3-7df9-4d8b-8b61-c48039a30431  Pengguna Google
#
#                                               userImage  \
# 7995  https://play-lh.googleusercontent.com/EGemoI2N...
# 7996  https://play-lh.googleusercontent.com/EGemoI2N...
# 7997  https://play-lh.googleusercontent.com/EGemoI2N...
# 7998  https://play-lh.googleusercontent.com/EGemoI2N...
# 7999  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                 content  score  thumbsUpCount  \
# 7995  Saya pengguna dari 2008 sampai sekarang, tapi ...      1              1
# 7996  pembelian paket internet 65000 pembayaran qris...      1              0
# ...

# %% [markdown]
# AMBIL DATA YANG DIBUTUHKAN

# %%
df_busu[['userName', 'score', 'at', 'content']].tail()
# Out:
#              userName  score                  at  \
# 7995  Pengguna Google      1 2026-05-12 06:50:48
# 7996  Pengguna Google      1 2026-05-12 06:45:12
# 7997  Pengguna Google      5 2026-05-12 06:43:27
# 7998  Pengguna Google      2 2026-05-12 06:42:48
# 7999  Pengguna Google      1 2026-05-12 06:41:49
#
#                                                 content
# 7995  Saya pengguna dari 2008 sampai sekarang, tapi ...
# 7996  pembelian paket internet 65000 pembayaran qris...
# 7997  mantap mudah kalau isi paket GK perlu keluar r...
# 7998  Banyak korupsi nya ini Telkomsel. dari masa te...
# 7999  Telkomsel ini kenapa jaringannya di riau lelet...

# %%
my_df = df_busu[['userName', 'score', 'at', 'content']]

# %%
#simpan dataset e dalam file
my_df.to_csv("DataSetMyTelkkomsel.csv", index = False)
